# %%
import pandas as pd
import matplotlib.pyplot as plt

data= pd.read_csv("clean_house_data.csv")

# %%
data.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  yr_built  yr_renovated  zipcode  \
# 0      5650     1.0           0     0  ...      1955             0    98178
# 1      7242     2.0           0     0  ...      1951          1991    98125
# 2     10000     1.0           0     0  ...      1933             0    98028
# 3      5000     1.0           0     0  ...      1965             0    98136
# 4      8080     1.0           0     0  ...      1987             0    98074
#
#        lat     long  sqft_living15  sqft_lot15  house_age  renovated  \
# 0  47.5112 -122.257           1340        5650         71          0
# 1  47.7210 -122.319           1690        7639         75          1
# 2  47.7379 -122.233           2720        8062         93          0
# 3  47.5208 -122.393           1360        5000         61          0
# 4  47.6168 -122.045           1800        7503         39          0
#
#    price_per_sqft
# 0      188.050847
# 1      209.338521
# 2      233.766234
# 3      308.163265
# 4      303.571429
#
# [5 rows x 24 columns]

# %%
# House age
data['house_age'] = 2026 - data['yr_built']

# Years since renovation
data['years_since_renovation'] = data['yr_renovated'].apply(
    lambda x: 0 if x == 0 else 2026 - x
)

# Total rooms
data['total_rooms'] = data['bedrooms'] + data['bathrooms']

# Living to lot ratio
data['living_lot_ratio'] = data['sqft_living'] / data['sqft_lot']

# Basement availability
data['has_basement'] = (data['sqft_basement'] > 0).astype(int)

# Renovated
data['renovated'] = (data['yr_renovated'] > 0).astype(int)

# Waterfront
data['waterfront'] = data['waterfront'].astype(int)

# View quality
data['view'] = data['view'].astype(int)

# Grade
data['grade'] = data['grade'].astype(int)

# %%
x= data.drop(columns=['id','date','price'])
y = data['price']

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(
    x,
    y,
    test_size=0.2,
    random_state=42
)

# %%
print(x_train.shape)
print(x_test.shape)
# Out:
# (17290, 25)
# (4323, 25)

# %%
import xgboost
print(xgboost.__version__)
# Out:
# 3.2.0

# %%
from xgboost import XGBRegressor

xgb = XGBRegressor(
    n_estimators=500,
    learning_rate=0.05,
    max_depth=6,
    subsample=0.8,
    colsample_bytree=0.8,
    random_state=42
)

xgb.fit(x_train, y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.8, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.05, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=6,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=500,
#              n_jobs=None, num_parallel_tree=None, ...)

# %%
pred = xgb.predict(x_test)

# %%
from sklearn.metrics import (
    mean_absolute_error,
    mean_squared_error,
    mean_absolute_percentage_error,
    r2_score
)

import numpy as np

mae = mean_absolute_error(y_test, pred)
rmse = np.sqrt(mean_squared_error(y_test, pred))
mape = mean_absolute_percentage_error(y_test, pred)
r2 = r2_score(y_test, pred)

print("MAE :", mae)
print("RMSE:", rmse)
print("MAPE:", mape)
print("R² :", r2)
# Out:
# MAE : 9682.244101318529
# RMSE: 30810.35533731173
# MAPE: 0.015162369631433395
# R² : 0.9937207392472027

# %%
importance = pd.Series(
    xgb.feature_importances_,
    index=x_train.columns
).sort_values(ascending=False)

plt.figure(figsize=(10,8))
importance.head(20).plot(kind='barh')
plt.title("Top 20 Important Features")
plt.show()

# %%
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from xgboost import XGBRegressor

model = XGBRegressor(random_state=42)

cv = KFold(
    n_splits=5,
    shuffle=True,
    random_state=42
)

scores = cross_val_score(
    model,
    x,
    y,
    cv=cv,
    scoring='r2'
)

print(scores)
print(scores.mean())
# Out:
# [0.99030685 0.98332544 0.9885052  0.99140004 0.99452568]
# 0.9896126410971187
